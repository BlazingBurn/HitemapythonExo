# %% [markdown]
# <a href="https://colab.research.google.com/github/BlazingBurn/HitemapythonExo/blob/main/analyse%20donnee/Exercice_data_visualisation_stats_descriptives.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Visualisation Statistiques descriptives**
# #### *Exercices*
#
# # I. **Visualisation d’un nuage de points et exploration des variables**
#
# Pour cette partie, nous allons utiliser le dataset suivante : ***house_pricing.csv*** que vous pouvez trouver dans le dossier Data Sources. Nous allons tenter de comprendre un peu mieux ce dataset par la visualisation.
#
#
# 1) Importez les librairies qu’il nous faut (pandas, seaborn, matplotlib, numpy)
#
# 2) Donnez la liste des variables présentes dans ce dataset ainsi que leur nature (sont elles qualitatives, quantitatives, discrète etc…) et leur type (float, int, str etc…)
#
# 3) En créant un nuage de points, regardez comment se comporte la colonne LotArea par rapport au SalesPrices
#
# 4) Affinez votre visualisation en ne gardant uniquement les maisons qui ont un LotArea inférieur à 20 000 pieds carrés et un prix inférieur à 500 000$
#
# 5) En créant un nuage de points, regardez la relation entre le LotFrontage et le LotArea
#
# 6) De la même manière, affinez votre visualisation en ne gardant uniquement les maisons qui ont un LotFrontage inférieur à 200 pieds carrés et un LotArea inférieur à 100000 pieds carré
#
# <br/>
#
# ### 1) Importez les librairies qu’il nous faut (pandas, seaborn, matplotlib, numpy)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2) Donnez la liste des variables présentes dans ce dataset ainsi que leur nature (sont elles qualitatives, quantitatives, discrète etc…) et leur type (float, int, str etc…)

# %%
dataHousePricing = pd.read_csv("house_pricing.csv")

print("La shape du dataSet est de : ",dataHousePricing.shape)

dataHousePricing.head()
# Out:
# La shape du dataSet est de :  (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
# ...

# %%
dataHousePricing
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
print("La liste des variables et leur type est le suivant : ",dataHousePricing.dtypes)
# Out:
# La liste des variables et leur type est le suivant :  Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
dataHousePricing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# int, float => quantitative
#
# object => categorielle
#
# #### **Exemple de problématique pour ce dataFrame : Est-ce que le prix de la maison est impactée par certaines caractéristiques ?**

# %% [markdown]
# ### 3) En créant un nuage de points, regardez comment se comporte la colonne LotArea par rapport au SalesPrices

# %%
# panda
dataHousePricing.plot.scatter("LotArea", "SalePrice", marker='o', c='blue')

# %%
# Apply the default theme
sns.set_theme()

# Create a visualization
sns.relplot(data=dataHousePricing,y="SalePrice",x="LotArea", height=6).set(title='Nuage de points - LotArea par rapport au SalePrice')

# %% [markdown]
# ### 4) Affinez votre visualisation en ne gardant uniquement les maisons qui ont un LotArea inférieur à 20 000 pieds carrés et un prix inférieur à 500 000$

# %%
# Create a visualization
sns.relplot(data=dataHousePricing[(dataHousePricing["SalePrice"] < 500000) & (dataHousePricing["LotArea"] < 20000)],y="SalePrice",x="LotArea",height=6,s=40).set(title="Nuage de point - inférieur 20000pieds et prix 500000€")

# %% [markdown]
# ### 5) En créant un nuage de points, regardez la relation entre le LotFrontage et le LotArea

# %%
# Create a visualization
sns.relplot(data=dataHousePricing,x="LotFrontage",y="LotArea", height=6).set(title="Nuage de point - relation LotFrontage et LotArea")

# %% [markdown]
# ### 6) De la même manière, affinez votre visualisation en ne gardant uniquement les maisons qui ont un LotFrontage inférieur à 200 pieds carrés et un LotArea inférieur à 100000 pieds carré

# %%
# Create a visualization
plt.figure(figsize=(20,5))

sns.relplot(data=dataHousePricing[(dataHousePricing.LotFrontage < 200) & (dataHousePricing.LotArea < 100000)],x="LotFrontage",y="LotArea", height=6).set(title="Nuage de point - inférieur LotArea 100000 pieds² et LotFrontage 200 pieds²")

# %% [markdown]
# # II. **Visualisation de relations continues**
#
# Pour cette partie, nous utiliserons le dataset suivant : ***sales_predictions.csv*** que vous pouvez trouver dans le dossier Data Sources.
#
# 1) Importez les librairies qu’il vous faut
#
# 2) En utilisant relplot(), construisez un graphique qui va vous permettre de voir l’évolution des prix par rapport au temps. Que pouvez vous voir ?
#
# 3) Corrigeons le problème de visualisation, en utilisant la fonction .sample() de Pandas, prenez un échantillons de 50 éléments dans votre dataset
#
# 4) Retentez de faire votre visualisation, créez une figure de taille (20,6). Que voyez vous ?
#
# 5) En utilisant la fonction pd.to_datetime(), convertissez votre colonne date en datetime
#
# 6) Retentez une dernière fois votre visualisation.
#
# <br/>
#
# ### 1) Importez les librairies qu’il vous faut

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataSalePrediction = pd.read_csv("sales_predictions.csv")

dataSalePrediction
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %% [markdown]
# #### **Exemple de problématique pour ce dataFrame : Le temps augmente t-il le prix d'un objet ?**

# %% [markdown]
# ### 2) En utilisant relplot(), construisez un graphique qui va vous permettre de voir l’évolution des prix par rapport au temps. Que pouvez vous voir ?

# %%
# Create a visualization
sns.relplot(data=dataSalePrediction,x="item_price", y="date", height=6).set(title="Nuage de point - evolution du prix par rapport au temps")

# %% [markdown]
# ### 3) Corrigeons le problème de visualisation, en utilisant la fonction .sample() de Pandas, prenez un échantillons de 50 éléments dans votre dataset

# %%
# Create a visualization
sns.relplot(data=dataSalePrediction.sample(n=50, random_state=1),x="item_price", y="date", height=7).set(title="Nuage de point - evolution du prix par rapport au temps (50 éléments)")

# %% [markdown]
# ### 4) Retentez de faire votre visualisation, créez une figure de taille (20,6). Que voyez vous ?

# %%
# Create a visualization
sns.relplot(data=dataSalePrediction.sample(n=50, random_state=1),x="item_price", y="date", height=6, sizes=(20,6)).set(title="Nuage de point - evolution du prix par rapport au temps (50 éléments)")

# %% [markdown]
# ### 5) En utilisant la fonction pd.to_datetime(), convertissez votre colonne date en datetime

# %%
datime = pd.to_datetime(dataSalePrediction['date'])
print(datime)
sns.relplot(data=dataSalePrediction.sample(n=50, random_state=1),y="item_price", x=pd.to_datetime(dataSalePrediction["date"]), height=6, sizes=(20,6)).set(title="Nuage de point - evolution du prix par rapport au temps (50 éléments) | date to datetime")
# Out:
# 0         2013-02-01
# 1         2013-03-01
# 2         2013-05-01
# 3         2013-06-01
# 4         2013-01-15
#              ...
# 2935844   2015-10-10
# 2935845   2015-09-10
# 2935846   2015-10-14
# 2935847   2015-10-22
# 2935848   2015-03-10
# Name: date, Length: 2935849, dtype: datetime64[ns]

# %% [markdown]
# ### 6) Retentez une dernière fois votre visualisation.

# %%
# Create a visualization
sns.lineplot(data=dataSalePrediction.sample(n=50, random_state=1),y="item_price", x=pd.to_datetime(dataSalePrediction["date"])).set(title="Nuage de point - evolution du prix par rapport au temps (50 éléments) | date to datetime")
# Out:
# [Text(0.5, 1.0, 'Nuage de point - evolution du prix par rapport au temps (50 éléments) | date to datetime')]

# %% [markdown]
# # III. **Visualisation de variables catégoriques**
#
# Pour cette partie, nous utiliserons le dataset suivant : ***ibm_hr_attrition.csv*** que vous pouvez trouver dans le dossier Data Sources
#
# 1) Importez les librairies qu’il vous faut
#
# 2) En utilisant catplot(), construisez un graphique qui vous permette de voir la distribution des personnes qui ont quitté l’entreprise par rapport à leur JobSatisfaction
#
# 3) Changez de graphique et utilisez plutôt un boxplot, que pouvez vous conclure ?
#
# 4) Peut-on dire grâce aux boxplot si une variable présente des valeurs aberrantes ?
#
# 5) Isolez les observations présentant des valeurs aberrantes pour la variable JobSatisfaction en fonction de la variable indiquant si ils ont quitté l’entreprise ou nom
#
# 6) Utilisez la méthode .describe de pandas pour obtenir un tableau récapitulatif des statistiques descriptives du dataset.
#
# 7) Comparez les individus présentant des valeurs aberrantes pour la variable JobSatisfaction avec les statistiques descriptives du dataset, remarquez vous des différences notoires ?
#
# 8) Faites de même avec le TotalWorkingYears. Que pouvez vous conclure ?
#
# 9) Remplacer les valeurs de la colonne Attrition par 1 pour Yes et 0 pour No
#
# 10) En utilisant un Histogramme, regardez la répartition du taux de départ par EducationField
#
# <br/>
#
# ### 2) En utilisant catplot(), construisez un graphique qui vous permette de voir la distribution des personnes qui ont quitté l’entreprise par rapport à leur JobSatisfaction

# %%
dataIbmHrAttrition = pd.read_csv("IBM_HR_ATTRITION.csv")

dataIbmHrAttrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
dataIbmHrAttrition
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
dataIbmHrAttrition.columns.tolist()
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
# Create a visualization
sns.catplot(data=dataIbmHrAttrition,y="Attrition", x="JobSatisfaction", height=7).set(title="graphique des personnes qui quitte l'entreprise en fonction de leur JobSatisfaction")

# %% [markdown]
# ### 3) Changez de graphique et utilisez plutôt un boxplot, que pouvez vous conclure ?

# %%
# Create a visualization
sns.boxplot(data=dataIbmHrAttrition,y="Attrition", x="JobSatisfaction").set(title="graphique des personnes qui quitte l'entreprise en fonction de leur JobSatisfaction - boxplot")
# Out:
# [Text(0.5, 1.0, "graphique des personnes qui quitte l'entreprise en fonction de leur JobSatisfaction - boxplot")]

# %% [markdown]
# ### 4) Peut-on dire grâce aux boxplot si une variable présente des valeurs aberrantes ?
# NON

# %% [markdown]
# ### 5) Isolez les observations présentant des valeurs aberrantes pour la variable JobSatisfaction en fonction de la variable indiquant si ils ont quitté l’entreprise ou nom

# %% [markdown]
# ### 6) Utilisez la méthode .describe de pandas pour obtenir un tableau récapitulatif des statistiques descriptives du dataset.

# %%
dataIbmHrAttrition.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ### 7) Comparez les individus présentant des valeurs aberrantes pour la variable JobSatisfaction avec les statistiques descriptives du dataset, remarquez vous des différences notoires ?

# %% [markdown]
# ### 8) Faites de même avec le TotalWorkingYears. Que pouvez vous conclure ?

# %%
# Create a visualization
sns.catplot(data=dataIbmHrAttrition,x="TotalWorkingYears", y="Attrition", height=7).set(title="graphique des personnes qui quitte l'entreprise en fonction de leur JobSatisfaction")

# %%
# Create a visualization
sns.boxplot(data=dataIbmHrAttrition,x="TotalWorkingYears", y="Attrition").set(title="graphique des personnes qui quitte l'entreprise en fonction de leur JobSatisfaction - boxplot")
# Out:
# [Text(0.5, 1.0, "graphique des personnes qui quitte l'entreprise en fonction de leur JobSatisfaction - boxplot")]

# %%
# Isolation des valeurs aberrantes
Q1 = dataIbmHrAttrition['TotalWorkingYears'].quantile(0.25)
Q3 = dataIbmHrAttrition['TotalWorkingYears'].quantile(0.75)
IQR = Q3 - Q1    #IQR is interquartile range. 

filter = (dataIbmHrAttrition['TotalWorkingYears'] < Q1 - (1.5 * IQR)) | (dataIbmHrAttrition['TotalWorkingYears'] > Q3 + (1.5 * IQR))
dataIbmHrAttrition.loc[filter]
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 18     53        No  Travel_Rarely       1219                   Sales
# 62     50        No  Travel_Rarely        989  Research & Development
# 85     56        No  Travel_Rarely       1400  Research & Development
# 98     58        No  Travel_Rarely        682                   Sales
# 105    59        No     Non-Travel       1420         Human Resources
# ...   ...       ...            ...        ...                     ...
# 1264   55        No  Travel_Rarely        478  Research & Development
# 1301   58        No     Non-Travel        350                   Sales
# 1331   48        No  Travel_Rarely       1224  Research & Development
# 1374   58        No  Travel_Rarely        605                   Sales
# 1401   55        No  Travel_Rarely        189         Human Resources
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# ...

# %%
dataIbmHrAttrition.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ### 9) Remplacer les valeurs de la colonne Attrition par 1 pour Yes et 0 pour No

# %%
# tmp = dataIbmHrAttrition.replace({'Attrition': {'Yes': True,'No': False}})
# tmp["Attrition"] = tmp["Attrition"].astype(int)

dataIbmHrAttrition.Attrition = dataIbmHrAttrition.Attrition.replace(to_replace = ['Yes', 'No'], value=[1,0])
print(dataIbmHrAttrition)
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ### 10) En utilisant un Histogramme, regardez la répartition du taux de départ par EducationField

# %%
# Create a visualization
sns.catplot(data=dataIbmHrAttrition,y="Attrition", x="EducationField", kind="bar", height=10).set(title="Histogramme du taux de départ par EducationField")

# %% [markdown]
# # Visualisation d’une distribution
#
# Continuons sur ibm_hr_attritition.csv
#
# 1) Importez les librairies qu’il vous faut
#
# 2) En utilisant distplot(), construisez un graphique qui permette de voir la distribution des revenues par mois chez IBM (MonthlyIncome)
#
# 3) On peut voir que les très haut salaires biaisent notre distribution, essayons de voir la distribution des salaires entre 0 et 5000$ / mois

# %% [markdown]
# # Visualisation d’une relation linéaire
#
# Toujours sur ibm_hr_attrition.csv
#
# 1) Importez les librairies qu’il vous faut
#
# 2) On voudrait connaître la probabilité de partir de la l’entreprise par rapport à la distance par rapport à la maison. Utilisez lmplot() pour visualiser cela. Que pouvez vous conclure ?
#
# 3) Tentez le cette fois avec le nombre d’années passées avec le Manager
# (YearsWithCurrManager), que pouvez vous conclure ?

# %% [markdown]
# # Visualisation d’une heatmap
#
# Revenons sur house_pricing.csv, et tentons de faire un peu de ce qu’on appelle communément : feature_engineering
#
# 1) Importez les librairies habituelles
#
# 2) Découpez votre dataset pour ne garder que les 15 dernieres colonnes
#
# 3) Créez une matrice de corrélation avec toutes les variables du Dataset
#
# 4) Créez une heatmap avec les différentes valeur de corrélation
#
# 5) Quel est le top 3 des features qu’on devrait garder pour prédire notre prix ?
#
# ### 2) Découpez votre dataset pour ne garder que les 15 dernieres colonnes

# %%
dataHousePricing = pd.read_csv("house_pricing.csv")

dataHousePricing.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
dataHousePricing15 = dataHousePricing.iloc[:,-15:]

print(dataHousePricing15)
# Out:
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# ...

# %% [markdown]
# ### 3) Créez une matrice de corrélation avec toutes les variables du Dataset

# %%
corr = dataHousePricing15.corr()

corr
# Out:
#                WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# WoodDeckSF       1.000000     0.058661      -0.125989  -0.032771    -0.074181
# OpenPorchSF      0.058661     1.000000      -0.093079  -0.005842     0.074304
# EnclosedPorch   -0.125989    -0.093079       1.000000  -0.037305    -0.082864
# 3SsnPorch       -0.032771    -0.005842      -0.037305   1.000000    -0.031436
# ScreenPorch     -0.074181     0.074304      -0.082864  -0.031436     1.000000
# PoolArea         0.073378     0.060762       0.054203  -0.007992     0.051307
# MiscVal         -0.009551    -0.018584       0.018361   0.000354     0.031946
# MoSold           0.021011     0.071255      -0.028887   0.029474     0.023217
# YrSold           0.022270    -0.057619      -0.009916   0.018645     0.010694
# SalePrice        0.324413     0.315856      -0.128578   0.044584     0.111447
#
#                PoolArea   MiscVal    MoSold    YrSold  SalePrice
# ...

# %% [markdown]
# ### 4) Créez une heatmap avec les différentes valeur de corrélation

# %%
f, ax = plt.subplots(figsize=(20,5))
sns.heatmap(corr, annot=True, ax=ax)

# %% [markdown]
# ### 5) Quel est le top 3 des features qu’on devrait garder pour prédire notre prix ?

# %% [markdown]
# # Formaliser des KPI
#
# 1) Se renseigner sur ce qu’est un KPI
#
# 2) Importez les bonnes librairies et le dataset resto.csv
#
# 3) Regardez les 10 premières lignes du dataset
#
# 4) Quelle est la taille de notre dataset ?
#
# 5) Affichez toutes les colonnes de notre dataset
#
# 6) Quel est l’item le plus commandé
#
# 7) Combien d’items ont été commandés au total chez Chipotle
#
# 8) Combien de chiffre d’affaire à realisé Chipotle ?
#
# 9) Quel est le revenu moyen par commande ?
